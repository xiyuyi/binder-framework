# %% [markdown]
# ## Data Science Practice problems notebook.
# Topic - Value of Energy Cost Savings Program for business in NYC.
#
# Download the data set about Value of [Energy Cost Saving Program](https://data.cityofnewyork.us/City-Government/Value-of-Energy-Cost-Savings-Program-Savings-for-B/bug8-9f3g) for businesses in New York City (under the "Export" option, there is a way to retrieve a CSV file). Answer the following questions.
#
# ### Questions:
# * Q1 - How many different companies are represented in the data set?
# * Q2 -  What is the total number of jobs created for businesses in Queens?
# * Q3 - How many different unique email domains names are there in the data set?
# * Q4 - Considering only NTAs with at least 5 listed businesses, what is the average total savings and the total jobs created for each NTA?
# * Q5 - Save your result for the previous question as a CSV file.

# %% [markdown]
# ### 1. load the data, and perform some initial exploration

# %%
import pandas as pd
fpath = './data/Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses.csv'
df = pd.read_csv(fpath)

# check the shape of the dataframe.
print('shape of the dataframe:')
print(df.shape)

# check the keys
print('keys of this dataframe:')
print(df.keys())

# have a breif view of the dataframe:
print('brief view of the dataframe:')
df.head()
# Out:
# shape of the dataframe:
# (2363, 30)
# keys of this dataframe:
# Index(['Period', 'Company Name', 'company contact', 'company email',
#        'company phone', 'Address', 'City', 'State', 'Postcode', 'Industry',
#        'Industry descr', 'Company Type', 'Current fulltime', 'Job created',
#        'Job retain', 'Effective Date', 'Total Savings',
#        'Savings from beginning receiving benefits', 'Gas Savings',
#        'Cogen savings', 'Electric Savings', 'Borough', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'BIN', 'BBL',
#        'Census Tract (2020)', 'Neighborhood Tabulation Area (NTA) (2020)'],
#       dtype='object')
# brief view of the dataframe:
#    Period                                 Company Name     company contact  \
# 0  FY2018                         139 ACA Realty, Inc.     Eitan Chandally
# 1  FY2018  141 Lake Avenue Realty c/o JR Produce, Inc.           Josef Raz
# 2  FY2018                       14-10 123rd Street LLC  Danica/Ivan Drazic
# 3  FY2018                      183 Lorriane Street LLC        Tom Sapienza
# 4  FY2018                    21st Century Optics, Inc.     Ralph Woythaler
#
#                        company email company phone              Address  \
# 0                  barbara@dial7.com    7187076123    43-23 35th Street
# 1                jrproduce@gmail.com    7183708782      141 Lake Avenue
# 2          ddrazic@atjelectrical.com    7183210117   14-10 123rd Street
# 3                tsapienza@KLCNY.com    2128405588  183 Lorraine Street
# 4  rwoythaler@21st centuryoptics.com    7183922310    47-00 33rd Street
#
#                City State  Postcode                          Industry  ...  \
# 0  Long Island City    NY     11101                        Commercial  ...
# 1     Staten Island    NY     10303  Wholesale/Warehouse/Distribution  ...
# 2     College Point    NY     11356                        Commercial  ...
# 3          Brooklyn    NY     11231  Wholesale/Warehouse/Distribution  ...
# 4  Lond Island City    NY     11101                     Manufacturing  ...
#
#   Electric Savings    Borough   Latitude  Longitude  Community Board  \
# 0              NaN     QUEENS  40.745706 -73.929565            402.0
# 1              NaN  STATEN IS  40.632845 -74.151048            501.0
# 2              NaN     QUEENS  40.785144 -73.844833            407.0
# 3              NaN   BROOKLYN  40.673106 -74.002300            306.0
# 4              NaN     QUEENS  40.742386 -73.932148            402.0
#
#   Council District        BIN           BBL  Census Tract (2020)  \
# 0             26.0  4003160.0  4.002220e+09              17902.0
# 1             49.0  5146740.0  5.011610e+09                239.0
# 2             19.0  4098344.0  4.040850e+09                929.0
# 3             38.0  3336622.0  3.005720e+09               5302.0
# 4             26.0  4003447.0  4.002520e+09              19901.0
#
#    Neighborhood Tabulation Area (NTA) (2020)
# 0                                     QN0202
# 1                                     SI0107
# 2                                     QN0701
# 3                                     BK0601
# 4                                     QN0202
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 2. Work on the questions.
#
# ### Q1. How many different companies are represented in the data set?

# %%
l=df['Company Name'].unique()
print('there are '+str(len(l))+' unique companies represented in the data set')
# Out:
# there are 787 unique companies represented in the data set

# %% [markdown]
# ### Q2 - What is the total number of jobs created for businesses in Queens?

# %%
# check the spelling of Queens in the Borough section
print('All the Borough:')
print(df['City'].unique())

# sum up all the jobs created for business in Queens:
jobs_in_queens = df[df['City']=='QUEENS']['Job created'].sum() + df[df['City']=='Queens']['Job created'].sum() 
print('total number of jobs created for businesses in Queens is ' + str(jobs_in_queens))
# Out:
# All the Borough:
# ['Long Island City' 'Staten Island' 'College Point' 'Brooklyn'
#  'Lond Island City' 'New York' 'Queens' 'Ozone Park' 'Forest Hills'
#  'Brooklyn,' 'QUEENS' 'New YOrk' 'Bronx' 'bronx' 'LONG ISLAND CITY' 'LIC'
#  'brooklyn' 'BRONX' 'Maspeth' nan 'BROOKLYN' 'Jamaica' 'Brookln'
#  'Mt. Vernon' 'Whitestone' 'GLENDALE' 'Flushing' 'Bronx,'
#  'Springfield Gardens' 'Bronx, NY' 'BROOKLYN HEIGHT' 'Brookyn' 'NEW YORK'
#  'Ridgewood' 'Glendale' 'Brooklym' 'Far Rockaway' 'Astoria'
#  'COLLEGE POINT' 'L I C' 'RIDGEWOOD' 'PORT MORRIS' 'Woodside' 'MASPETH'
#  'INWOOD' 'L.I.C.' 'STATEN ISLAND' 'NY' 'Memphis' 'St Louis'
#  'Queens Village' 'Hicksville' 'Middle Village' 'Pacoima']
# total number of jobs created for businesses in Queens is 12257.0

# %% [markdown]
# ### Q3 - How many different unique email domains names are there in the data set?

# %%
import numpy as np
# keep in mind that "emails" and :email domains names: are different.

# first define a transform function to calculate the email domain name:
def get_email_domain_name(email):
    if isinstance(email, str):
        domain_name = email.split('@')[-1].split('.com')[0]
    else:
        domain_name = np.nan
    return domain_name

# create an extra column in the dataframe to store the domain name of the company email.
df['company email domain name'] = df['company email'].apply(get_email_domain_name)

# calculate the totla number of unique domains names:
ucdn = df['company email domain name'].unique()
print('total number of unique email domains names is: ' + str(len(ucdn)))
# Out:
# total number of unique email domains names is: 601

# %% [markdown]
# ### Q4 - Considering only NTAs with at least 5 listed businesses, what is the average total savings and the total jobs created for each NTA?

# %%
# first, tag each row that has how many fellow businesses within the same NTA.
df['business count per NTA'] = df.groupby('Neighborhood Tabulation Area (NTA) (2020)')\
                    ['Neighborhood Tabulation Area (NTA) (2020)'].transform('count')

# filter out only the NTAs with at least 5 listed businesses
df2=df[df['business count per NTA'] >=5]

# find NTA count and convert to dataframe.
df_byNTA=df2.groupby('Neighborhood Tabulation Area (NTA) (2020)')['business count per NTA'].count().to_frame().reset_index()

# find the average total savings grouped by NTA
df3=df2.groupby('Neighborhood Tabulation Area (NTA) (2020)')['Total Savings'].mean().to_frame().reset_index()
df_byNTA['Average Total Savings'] = df3['Total Savings']

df4=df2.groupby('Neighborhood Tabulation Area (NTA) (2020)')['Job created'].mean().to_frame().reset_index()
df_byNTA['Average Job created'] = df4['Job created']

# %%
# visualize the result
import seaborn as sns
import matplotlib.pyplot as plt
cm = sns.light_palette("green", as_cmap=True)
plt.figure()
df_byNTA.style.background_gradient(cmap=cm)
# plt.subplot(122)
# ave_tjc.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_2fdda_row0_col1 {
#   background-color: #a7d2a7;
#   color: #000000;
# }
# #T_2fdda_row0_col2, #T_2fdda_row1_col1, #T_2fdda_row1_col3, #T_2fdda_row9_col3, #T_2fdda_row15_col3, #T_2fdda_row17_col2, #T_2fdda_row22_col1, #T_2fdda_row25_col1, #T_2fdda_row28_col3, #T_2fdda_row30_col2, #T_2fdda_row32_col1, #T_2fdda_row41_col2, #T_2fdda_row45_col3, #T_2fdda_row56_col2, #T_2fdda_row62_col1, #T_2fdda_row65_col1 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_2fdda_row0_col3, #T_2fdda_row2_col1, #T_2fdda_row9_col1, #T_2fdda_row16_col2, #T_2fdda_row17_col1, #T_2fdda_row19_col1, #T_2fdda_row30_col3, #T_2fdda_row33_col1, #T_2fdda_row36_col3, #T_2fdda_row39_col2, #T_2fdda_row39_col3, #T_2fdda_row47_col2, #T_2fdda_row51_col1, #T_2fdda_row51_col2, #T_2fdda_row52_col3, #T_2fdda_row66_col2, #T_2fdda_row69_col1, #T_2fdda_row69_col3 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_2fdda_row1_col2, #T_2fdda_row7_col2, #T_2fdda_row21_col2, #T_2fdda_row25_col3, #T_2fdda_row27_col3, #T_2fdda_row28_col1, #T_2fdda_row29_col1, #T_2fdda_row32_col2, #T_2fdda_row38_col1, #T_2fdda_row53_col2, #T_2fdda_row54_col2, #T_2fdda_row55_col1, #T_2fdda_row60_col2, #T_2fdda_row66_col1 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_2fdda_row2_col2, #T_2fdda_row3_col2, #T_2fdda_row27_col2, #T_2fdda_row33_col2, #T_2fdda_row40_col2, #T_2fdda_row46_col3, #T_2fdda_row53_col3, #T_2fdda_row68_col2 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_2fdda_row2_col3, #T_2fdda_row4_col3, #T_2fdda_row5_col3, #T_2fdda_row7_col3, #T_2fdda_row10_col3, #T_2fdda_row12_col3, #T_2fdda_row14_col3, #T_2fdda_row16_col3, #T_2fdda_row18_col3, #T_2fdda_row19_col3, #T_2fdda_row21_col3, #T_2fdda_row23_col3, #T_2fdda_row24_col3, #T_2fdda_row29_col3, #T_2fdda_row31_col3, #T_2fdda_row33_col3, #T_2fdda_row34_col3, #T_2fdda_row38_col3, #T_2fdda_row40_col3, #T_2fdda_row42_col3, #T_2fdda_row47_col3, #T_2fdda_row56_col3, #T_2fdda_row58_col3, #T_2fdda_row59_col3, #T_2fdda_row61_col3, #T_2fdda_row62_col3, #T_2fdda_row64_col3, #T_2fdda_row65_col3, #T_2fdda_row67_col3, #T_2fdda_row68_col3, #T_2fdda_row71_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2fdda_row3_col1 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_2fdda_row3_col3, #T_2fdda_row8_col1, #T_2fdda_row13_col3, #T_2fdda_row15_col2, #T_2fdda_row22_col3, #T_2fdda_row26_col2, #T_2fdda_row36_col2, #T_2fdda_row37_col2, #T_2fdda_row48_col3, #T_2fdda_row52_col2, #T_2fdda_row59_col2, #T_2fdda_row61_col1, #T_2fdda_row64_col2, #T_2fdda_row71_col1 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_2fdda_row4_col1, #T_2fdda_row4_col2, #T_2fdda_row10_col2, #T_2fdda_row25_col2, #T_2fdda_row26_col3, #T_2fdda_row43_col2, #T_2fdda_row44_col2, #T_2fdda_row45_col1, #T_2fdda_row49_col2, #T_2fdda_row50_col3, #T_2fdda_row52_col1, #T_2fdda_row55_col3, #T_2fdda_row57_col3, #T_2fdda_row60_col1, #T_2fdda_row63_col1, #T_2fdda_row66_col3 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_2fdda_row5_col1 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_2fdda_row5_col2 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_2fdda_row6_col1, #T_2fdda_row9_col2, #T_2fdda_row31_col1, #T_2fdda_row50_col2, #T_2fdda_row55_col2, #T_2fdda_row60_col3, #T_2fdda_row62_col2, #T_2fdda_row63_col2, #T_2fdda_row69_col2 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_2fdda_row6_col2, #T_2fdda_row68_col1 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_2fdda_row6_col3, #T_2fdda_row15_col1, #T_2fdda_row31_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_2fdda_row7_col1, #T_2fdda_row58_col2 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_2fdda_row8_col2 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_2fdda_row8_col3, #T_2fdda_row12_col1, #T_2fdda_row23_col2, #T_2fdda_row24_col2, #T_2fdda_row37_col1, #T_2fdda_row37_col3, #T_2fdda_row41_col3, #T_2fdda_row42_col2, #T_2fdda_row61_col2 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_2fdda_row10_col1 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_2fdda_row11_col1, #T_2fdda_row46_col2 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_2fdda_row11_col2 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_2fdda_row11_col3 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_2fdda_row12_col2, #T_2fdda_row20_col1, #T_2fdda_row28_col2, #T_2fdda_row38_col2, #T_2fdda_row57_col2 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_2fdda_row13_col1 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# #T_2fdda_row13_col2, #T_2fdda_row20_col3, #T_2fdda_row35_col1, #T_2fdda_row43_col3, #T_2fdda_row45_col2, #T_2fdda_row48_col2, #T_2fdda_row49_col3, #T_2fdda_row65_col2, #T_2fdda_row70_col1 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_2fdda_row14_col1, #T_2fdda_row18_col1, #T_2fdda_row20_col2, #T_2fdda_row21_col1, #T_2fdda_row23_col1, #T_2fdda_row24_col1, #T_2fdda_row35_col3, #T_2fdda_row40_col1, #T_2fdda_row42_col1, #T_2fdda_row44_col3, #T_2fdda_row54_col3, #T_2fdda_row56_col1, #T_2fdda_row58_col1, #T_2fdda_row64_col1, #T_2fdda_row67_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_2fdda_row14_col2, #T_2fdda_row34_col1, #T_2fdda_row51_col3 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_2fdda_row16_col1, #T_2fdda_row57_col1 {
#   background-color: #c7e1c7;
#   color: #000000;
# }
# #T_2fdda_row17_col3 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_2fdda_row18_col2, #T_2fdda_row22_col2 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_2fdda_row19_col2 {
#   background-color: #6db56d;
#   color: #f1f1f1;
# }
# #T_2fdda_row26_col1 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_2fdda_row27_col1 {
#   background-color: #82c082;
#   color: #000000;
# }
# #T_2fdda_row29_col2 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_2fdda_row30_col1, #T_2fdda_row54_col1 {
#   background-color: #e0eedf;
#   color: #000000;
# }
# #T_2fdda_row32_col3, #T_2fdda_row49_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_2fdda_row34_col2 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_2fdda_row35_col2 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_2fdda_row36_col1, #T_2fdda_row41_col1, #T_2fdda_row44_col1, #T_2fdda_row59_col1 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_2fdda_row39_col1 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_2fdda_row43_col1 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_2fdda_row46_col1 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_2fdda_row47_col1, #T_2fdda_row63_col3 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_2fdda_row48_col1 {
#   background-color: #4ca54c;
#   color: #f1f1f1;
# }
# #T_2fdda_row50_col1 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_2fdda_row53_col1 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_2fdda_row67_col2 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_2fdda_row70_col2 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_2fdda_row70_col3 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_2fdda_row71_col2 {
#   background-color: #279327;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2fdda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fdda_level0_col0" class="col_heading level0 col0" >Neighborhood Tabulation Area (NTA) (2020)</th>
#       <th id="T_2fdda_level0_col1" class="col_heading level0 col1" >business count per NTA</th>
#       <th id="T_2fdda_level0_col2" class="col_heading level0 col2" >Average Total Savings</th>
#       <th id="T_2fdda_level0_col3" class="col_heading level0 col3" >Average Job created</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fdda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fdda_row0_col0" class="data row0 col0" >BK0101</td>
#       <td id="T_2fdda_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_2fdda_row0_col2" class="data row0 col2" >10367.961795</td>
#       <td id="T_2fdda_row0_col3" class="data row0 col3" >5.333333</td>
#     </tr>
#     <tr>
#       <th id="T_2fdda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fdda_row1_col0" class=

# %% [markdown]
# ### Q5 - Save your result for the previous question as a CSV file.

# %%
result_path = './data/Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_result.csv'
df_byNTA.to_csv(result_path, index=False)

# %% [markdown]
# ### Q6 - Create the following visualizations

# %% [markdown]
# 1. scatter plot of jobs created versus average savings. Use both a standard and a logarithmic scale for the average savings.
#
# 2. histogram of the log of the average total savings.
#
# 3. line plot of the total jobs created for each month.

# %%
# plot the Average Job careated v.s. Averate Total Savings (std scale)
import altair as alt
alt.Chart(df_byNTA)\
.mark_point()\
.encode(x='Average Total Savings',y='Average Job created')\
.properties(title='Average Job careated v.s. Averate Total Savings (std scale)',
           width=800,
        height=300)
# Out:
# alt.Chart(...)

# %%
# plot the Average Job careated v.s. Averate Total Savings (log scale)
alt.Chart(df_byNTA)\
.mark_point()\
.encode(x=alt.X('Average Total Savings', scale=alt.Scale(type='log',domain=[1,100000])),\
        y='Average Job created')\
.properties(title='Average Job careated v.s. Averate Total Savings (log scale)',
           width=800,
        height=300)
# Out:
# alt.Chart(...)

# %%
# histogram of the log of the average total savings.
alt.Chart(df_byNTA)\
.mark_bar()\
.encode(x=alt.X('Average Total Savings',
                bin = alt.BinParams(maxbins = 200),
                scale=alt.Scale(type='log',domain=[5000, 200000])),
        y = 'count()')
# Out:
# alt.Chart(...)

# %%
# line plot of the total jobs created for each month.
alt.Chart(df_byNTA)\
.mark_line()\
.encode(x=alt.X('Average Total Savings',
                bin = alt.BinParams(maxbins = 200),
                scale=alt.Scale(type='log',domain=[5000, 200000])),
        y = 'count()')

# %%
k=df[df['']>0]
# Out:
# array(['Long Island City', 'Staten Island', 'College Point', 'Brooklyn',
#        'Lond Island City', 'New York', 'Queens', 'Ozone Park',
#        'Forest Hills', 'Brooklyn,', 'QUEENS', 'New YOrk', 'Bronx',
#        'bronx', 'LONG ISLAND CITY', 'LIC', 'brooklyn', 'BRONX', 'Maspeth',
#        nan, 'BROOKLYN', 'Jamaica', 'Brookln', 'Mt. Vernon', 'Whitestone',
#        'GLENDALE', 'Flushing', 'Bronx,', 'Springfield Gardens',
#        'Bronx, NY', 'BROOKLYN HEIGHT', 'Brookyn', 'NEW YORK', 'Ridgewood',
#        'Glendale', 'Brooklym', 'Far Rockaway', 'Astoria', 'COLLEGE POINT',
#        'L I C', 'RIDGEWOOD', 'PORT MORRIS', 'Woodside', 'MASPETH',
#        'INWOOD', 'L.I.C.', 'STATEN ISLAND', 'NY', 'Memphis', 'St Louis',
#        'Queens Village', 'Hicksville', 'Middle Village', 'Pacoima'],
#       dtype=object)

# %%
df.keys().unique()
# Out:
# Index(['Period', 'Company Name', 'company contact', 'company email',
#        'company phone', 'Address', 'City', 'State', 'Postcode', 'Industry',
#        'Industry descr', 'Company Type', 'Current fulltime', 'Job created',
#        'Job retain', 'Effective Date', 'Total Savings',
#        'Savings from beginning receiving benefits', 'Gas Savings',
#        'Cogen savings', 'Electric Savings', 'Borough', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'BIN', 'BBL',
#        'Census Tract (2020)', 'Neighborhood Tabulation Area (NTA) (2020)',
#        'company email domain name', 'business count per NTA'],
#       dtype='object')

# %%
df['BBL']
# Out:
# 0       4.002220e+09
# 1       5.011610e+09
# 2       4.040850e+09
# 3       3.005720e+09
# 4       4.002520e+09
#             ...
# 2358    3.024720e+09
# 2359    5.011610e+09
# 2360             NaN
# 2361    3.011260e+09
# 2362    4.005890e+09
# Name: BBL, Length: 2363, dtype: float64

# %% [markdown]
# -- end --
